# %%
# Importing necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.MNIST(root='./data', train=False, transform=transform, download=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)
# Out:
# cuda
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 122006629.90it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 98967070.12it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 73322922.75it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 2572310.12it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# # Loading Weight Distributions - without dropout

# %%
import json
import numpy as np
import torch

# Read the JSON file
with open("weight_history.json", "r") as json_file:
    json_data = json.load(json_file)

def convert_to_original_format(obj):
    if isinstance(obj, list):
        if len(obj) > 0 and isinstance(obj[0], list):
            if len(obj[0]) > 0 and isinstance(obj[0][0], list):
                return [[[torch.tensor(array) for array in sublist] for sublist in item] for item in obj]
            else:
                return [[torch.tensor(array) for array in sublist] for sublist in obj]
        else:
            return [torch.tensor(array) for array in obj]
    else:
        return obj

# Convert the JSON data back to the original format
weight_history02 = convert_to_original_format(json_data)

# Now you have 'original_weight_history' as the Python list

# Sample check to verify the data type
if isinstance(weight_history02, list) and \
   isinstance(weight_history02[0], list) and \
   isinstance(weight_history02[0][0], list) and \
   isinstance(weight_history02[0][0][0], torch.Tensor):
    print("Successfully loaded the original Python list.")
else:
    print("Loaded data does not match the expected format.")

# You can access the elements of the original list 'original_weight_history' as needed.
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-de94a617b28f> in <cell line: 6>()
#       5 # Read the JSON file
#       6 with open("weight_history.json", "r") as json_file:
# ----> 7     json_data = json.load(json_file)
#       8
#       9 def convert_to_original_format(obj):
#
# /usr/lib/python3.10/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
# ...

# %% [markdown]
# # Loading Weight Distributions - with dropout

# %%
import json
import numpy as np
import torch

# Read the JSON file
with open("0.2_weight_history_dropout.json", "r") as json_file:
    json_data = json.load(json_file)

def convert_to_original_format(obj):
    if isinstance(obj, list):
        if len(obj) > 0 and isinstance(obj[0], list):
            if len(obj[0]) > 0 and isinstance(obj[0][0], list):
                return [[[torch.tensor(array) for array in sublist] for sublist in item] for item in obj]
            else:
                return [[torch.tensor(array) for array in sublist] for sublist in obj]
        else:
            return [torch.tensor(array) for array in obj]
    else:
        return obj

# Convert the JSON data back to the original format
weight_history_dropout02 = convert_to_original_format(json_data)

# Now you have 'original_weight_history' as the Python list

# Sample check to verify the data type
if isinstance(weight_history_dropout02, list) and \
   isinstance(weight_history_dropout02[0], list) and \
   isinstance(weight_history_dropout02[0][0], list) and \
   isinstance(weight_history_dropout02[0][0][0], torch.Tensor):
    print("Successfully loaded the original Python list.")
else:
    print("Loaded data does not match the expected format.")

# You can access the elements of the original list 'original_weight_history' as needed.
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-6-0ac65d4ccd8c> in <cell line: 6>()
#       5 # Read the JSON file
#       6 with open("0.2_weight_history_dropout.json", "r") as json_file:
# ----> 7     json_data = json.load(json_file)
#       8
#       9 def convert_to_original_format(obj):
#
# /usr/lib/python3.10/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
# ...

# %%
import json
import numpy as np
import torch

# Read the JSON file
with open("0.5_weight_history_dropout.json", "r") as json_file:
    json_data = json.load(json_file)

def convert_to_original_format(obj):
    if isinstance(obj, list):
        if len(obj) > 0 and isinstance(obj[0], list):
            if len(obj[0]) > 0 and isinstance(obj[0][0], list):
                return [[[torch.tensor(array) for array in sublist] for sublist in item] for item in obj]
            else:
                return [[torch.tensor(array) for array in sublist] for sublist in obj]
        else:
            return [torch.tensor(array) for array in obj]
    else:
        return obj

# Convert the JSON data back to the original format
weight_history_dropout05 = convert_to_original_format(json_data)

# Now you have 'original_weight_history' as the Python list

# Sample check to verify the data type
if isinstance(weight_history_dropout05, list) and \
   isinstance(weight_history_dropout05[0], list) and \
   isinstance(weight_history_dropout05[0][0], list) and \
   isinstance(weight_history_dropout05[0][0][0], torch.Tensor):
    print("Successfully loaded the original Python list.")
else:
    print("Loaded data does not match the expected format.")

# You can access the elements of the original list 'original_weight_history' as needed.
# Out:
# Successfully loaded the original Python list.

# %%
import json
import numpy as np
import torch

# Read the JSON file
with open("0.7_weight_history_dropout.json", "r") as json_file:
    json_data = json.load(json_file)

def convert_to_original_format(obj):
    if isinstance(obj, list):
        if len(obj) > 0 and isinstance(obj[0], list):
            if len(obj[0]) > 0 and isinstance(obj[0][0], list):
                return [[[torch.tensor(array) for array in sublist] for sublist in item] for item in obj]
            else:
                return [[torch.tensor(array) for array in sublist] for sublist in obj]
        else:
            return [torch.tensor(array) for array in obj]
    else:
        return obj

# Convert the JSON data back to the original format
weight_history_dropout07 = convert_to_original_format(json_data)

# Now you have 'original_weight_history' as the Python list

# Sample check to verify the data type
if isinstance(weight_history_dropout07, list) and \
   isinstance(weight_history_dropout07[0], list) and \
   isinstance(weight_history_dropout07[0][0], list) and \
   isinstance(weight_history_dropout07[0][0][0], torch.Tensor):
    print("Successfully loaded the original Python list.")
else:
    print("Loaded data does not match the expected format.")

# You can access the elements of the original list 'original_weight_history' as needed.
# Out:
# Successfully loaded the original Python list.

# %% [markdown]
# # Plot of KL Divergence

# %%
print(len(weight_history02[1]))
# Out:
# 404

# %%
print(len(weight_history02[0][250][0][0]))
# Out:
# 784

# %%
import matplotlib.pyplot as plt
import torch
from scipy.special import kl_div

num_epochs = 10
number_experiments = 10

# Initialize lists to store standard deviations for each layer across epochs
weight_history02_std_deviations_hidden1 = []
weight_history02_std_deviations_hidden2 = []
weight_history02_std_deviations_output = []

# Loop over each epoch - 10 times
for epoch in range(num_epochs):
    kl_divergences = [[0.0] * 127, [0.0] * 63, [0.0] * 9]  # Store KL divergences for each layer
    hidden1_idx = 0
    hidden2_idx = 0
    output_idx = 0
    for idx in range(0, 404, 2):
        if idx < 254:
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history02[epoch][idx][0][0],
                                  weight_history02[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[0][hidden1_idx] += kl_divergence
            hidden1_idx += 1
        elif idx < 382 and idx > 254 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history02[epoch][idx][0][0],
                                  weight_history02[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[1][hidden2_idx] += kl_divergence
            hidden2_idx += 1
        elif idx < 402 and idx > 382 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history02[epoch][idx][0][0],
                                  weight_history02[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[2][output_idx] += kl_divergence
            output_idx += 1

    # Divide each KL divergence by number_experiments (number of experiments)
    for i in range(3):
        kl_divergences[i] = [kl / number_experiments for kl in kl_divergences[i]]

    # Calculate the standard deviation for each layer and store it for this epoch
    std_hidden1 = torch.std(torch.tensor(kl_divergences[0]))
    std_hidden2 = torch.std(torch.tensor(kl_divergences[1]))
    std_output = torch.std(torch.tensor(kl_divergences[2]))

    weight_history02_std_deviations_hidden1.append(std_hidden1.item())
    weight_history02_std_deviations_hidden2.append(std_hidden2.item())
    weight_history02_std_deviations_output.append(std_output.item())

# Create a single subplot for all three layers
fig, ax = plt.subplots(figsize=(8, 6))

# Plot standard deviation of KL divergence for Hidden Layer 1
ax.plot(range(1, num_epochs + 1), weight_history02_std_deviations_hidden1, marker='o', linestyle='-', color='blue', label='Hidden Layer 1')

# Plot standard deviation of KL divergence for Hidden Layer 2
ax.plot(range(1, num_epochs + 1), weight_history02_std_deviations_hidden2, marker='o', linestyle='-', color='green', label='Hidden Layer 2')

# Plot standard deviation of KL divergence for Output Layer
ax.plot(range(1, num_epochs + 1), weight_history02_std_deviations_output, marker='o', linestyle='-', color='red', label='Output Layer')

# Set titles and labels
ax.set_title('Standard Deviation of KL Divergence - no dropout')
ax.set_xlabel('Epoch')
ax.set_ylabel('Standard Deviation')

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Initialize lists to store standard deviations for each layer across epochs
weight_history_dropout_02_std_deviations_hidden1 = []
weight_history_dropout_02_std_deviations_hidden2 = []
weight_history_dropout_02_std_deviations_output = []

# Loop over each epoch - 10 times
for epoch in range(num_epochs):
    kl_divergences = [[0.0] * 127, [0.0] * 63, [0.0] * 9]  # Store KL divergences for each layer
    hidden1_idx = 0
    hidden2_idx = 0
    output_idx = 0
    for idx in range(0, 404, 2):
        if idx < 254:
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout02[epoch][idx][0][0],
                                  weight_history_dropout02[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[0][hidden1_idx] += kl_divergence
            hidden1_idx += 1
        elif idx < 382 and idx > 254 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout02[epoch][idx][0][0],
                                  weight_history_dropout02[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[1][hidden2_idx] += kl_divergence
            hidden2_idx += 1
        elif idx < 402 and idx > 382 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout02[epoch][idx][0][0],
                                  weight_history_dropout02[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[2][output_idx] += kl_divergence
            output_idx += 1

    # Divide each KL divergence by number_experiments (number of experiments)
    for i in range(3):
        kl_divergences[i] = [kl / number_experiments for kl in kl_divergences[i]]

    # Calculate the standard deviation for each layer and store it for this epoch
    std_hidden1 = torch.std(torch.tensor(kl_divergences[0]))
    std_hidden2 = torch.std(torch.tensor(kl_divergences[1]))
    std_output = torch.std(torch.tensor(kl_divergences[2]))

    weight_history_dropout_02_std_deviations_hidden1.append(std_hidden1.item())
    weight_history_dropout_02_std_deviations_hidden2.append(std_hidden2.item())
    weight_history_dropout_02_std_deviations_output.append(std_output.item())

# %%
# Initialize lists to store standard deviations for each layer across epochs
weight_history_dropout_05_std_deviations_hidden1 = []
weight_history_dropout_05_std_deviations_hidden2 = []
weight_history_dropout_05_std_deviations_output = []

# Loop over each epoch - 10 times
for epoch in range(num_epochs):
    kl_divergences = [[0.0] * 127, [0.0] * 63, [0.0] * 9]  # Store KL divergences for each layer
    hidden1_idx = 0
    hidden2_idx = 0
    output_idx = 0
    for idx in range(0, 404, 2):
        if idx < 254:
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout05[epoch][idx][0][0],
                                  weight_history_dropout05[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[0][hidden1_idx] += kl_divergence
            hidden1_idx += 1
        elif idx < 382 and idx > 254 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout05[epoch][idx][0][0],
                                  weight_history_dropout05[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[1][hidden2_idx] += kl_divergence
            hidden2_idx += 1
        elif idx < 402 and idx > 382 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout05[epoch][idx][0][0],
                                  weight_history_dropout05[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[2][output_idx] += kl_divergence
            output_idx += 1

    # Divide each KL divergence by number_experiments (number of experiments)
    for i in range(3):
        kl_divergences[i] = [kl / number_experiments for kl in kl_divergences[i]]

    # Calculate the standard deviation for each layer and store it for this epoch
    std_hidden1 = torch.std(torch.tensor(kl_divergences[0]))
    std_hidden2 = torch.std(torch.tensor(kl_divergences[1]))
    std_output = torch.std(torch.tensor(kl_divergences[2]))

    weight_history_dropout_05_std_deviations_hidden1.append(std_hidden1.item())
    weight_history_dropout_05_std_deviations_hidden2.append(std_hidden2.item())
    weight_history_dropout_05_std_deviations_output.append(std_output.item())

# %%
# Initialize lists to store standard deviations for each layer across epochs
weight_history_dropout_07_std_deviations_hidden1 = []
weight_history_dropout_07_std_deviations_hidden2 = []
weight_history_dropout_07_std_deviations_output = []

# Loop over each epoch - 10 times
for epoch in range(num_epochs):
    kl_divergences = [[0.0] * 127, [0.0] * 63, [0.0] * 9]  # Store KL divergences for each layer
    hidden1_idx = 0
    hidden2_idx = 0
    output_idx = 0
    for idx in range(0, 404, 2):
        if idx < 254:
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout07[epoch][idx][0][0],
                                  weight_history_dropout07[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[0][hidden1_idx] += kl_divergence
            hidden1_idx += 1
        elif idx < 382 and idx > 254 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout07[epoch][idx][0][0],
                                  weight_history_dropout07[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[1][hidden2_idx] += kl_divergence
            hidden2_idx += 1
        elif idx < 402 and idx > 382 :
            # Calculate the KL divergence
            kl_divergence = kl_div(weight_history_dropout07[epoch][idx][0][0],
                                  weight_history_dropout07[epoch][idx + 2][0][0])
            kl_divergence = [kl.item() for kl in kl_divergence if kl != float('inf')]
            kl_divergence = sum(kl_divergence)
            kl_divergences[2][output_idx] += kl_divergence
            output_idx += 1

    # Divide each KL divergence by number_experiments (number of experiments)
    for i in range(3):
        kl_divergences[i] = [kl / number_experiments for kl in kl_divergences[i]]

    # Calculate the standard deviation for each layer and store it for this epoch
    std_hidden1 = torch.std(torch.tensor(kl_divergences[0]))
    std_hidden2 = torch.std(torch.tensor(kl_divergences[1]))
    std_output = torch.std(torch.tensor(kl_divergences[2]))

    weight_history_dropout_07_std_deviations_hidden1.append(std_hidden1.item())
    weight_history_dropout_07_std_deviations_hidden2.append(std_hidden2.item())
    weight_history_dropout_07_std_deviations_output.append(std_output.item())

# %%
# Hidden Layer 1
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(range(1, num_epochs + 1), weight_history02_std_deviations_hidden1 , marker='o', linestyle='-', color='blue', label='no dropout')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_02_std_deviations_hidden1, marker='o', linestyle='-', color='red', label='p=0.2')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_05_std_deviations_hidden1, marker='o', linestyle='-', color='purple', label='p=0.5')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_07_std_deviations_hidden1, marker='o', linestyle='-', color='pink', label='p=0.7')

# Set titles and labels
ax.set_title('Standard Deviation of KL Divergence for Hidden Layer 1')
ax.set_xlabel('Epoch')
ax.set_ylabel('Standard Deviation')

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Hidden Layer 2
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(range(1, num_epochs + 1), weight_history02_std_deviations_hidden2 , marker='o', linestyle='-', color='blue', label='no dropout')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_02_std_deviations_hidden2, marker='o', linestyle='-', color='red', label='p=0.2')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_05_std_deviations_hidden2, marker='o', linestyle='-', color='purple', label='p=0.5')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_07_std_deviations_hidden2, marker='o', linestyle='-', color='pink', label='p=0.7')

# Set titles and labels
ax.set_title('Standard Deviation of KL Divergence for Hidden Layer 2')
ax.set_xlabel('Epoch')
ax.set_ylabel('Standard Deviation')

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Output Layer
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(range(1, num_epochs + 1), weight_history02_std_deviations_output , marker='o', linestyle='-', color='blue', label='no dropout')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_02_std_deviations_output, marker='o', linestyle='-', color='red', label='p=0.2')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_05_std_deviations_output, marker='o', linestyle='-', color='purple', label='p=0.5')
ax.plot(range(1, num_epochs + 1), weight_history_dropout_07_std_deviations_output, marker='o', linestyle='-', color='pink', label='p=0.7')

# Set titles and labels
ax.set_title('Standard Deviation of KL Divergence for Output Layer')
ax.set_xlabel('Epoch')
ax.set_ylabel('Standard Deviation')

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
print(weight_history02_std_deviations_hidden1)
print(weight_history_dropout_02_std_deviations_hidden1)
print(weight_history_dropout_05_std_deviations_hidden1)
print(weight_history_dropout_07_std_deviations_hidden1)
# Out:
# [0.0545489639043808, 0.05590958148241043, 0.0537923164665699, 0.05039219185709953, 0.050204671919345856, 0.05221119895577431, 0.050743572413921356, 0.057681839913129807, 0.0551048219203949, 0.05138359218835831]
# [0.06623842567205429, 0.06472449749708176, 0.06766928732395172, 0.07047824561595917, 0.0695401206612587, 0.06653094291687012, 0.06605803221464157, 0.0660548135638237, 0.0644109845161438, 0.06610424071550369]
# [0.06257322430610657, 0.062275394797325134, 0.061037108302116394, 0.060058556497097015, 0.06477078795433044, 0.06360700726509094, 0.0627366155385971, 0.06267354637384415, 0.06370340287685394, 0.06387650966644287]
# [0.06687668710947037, 0.061830487102270126, 0.06643378734588623, 0.06555219739675522, 0.0676904246211052, 0.0699421837925911, 0.07269392162561417, 0.06653346121311188, 0.0719568058848381, 0.07460831105709076]

# %%
print(weight_history02_std_deviations_hidden2)
print(weight_history_dropout_02_std_deviations_hidden2)
print(weight_history_dropout_05_std_deviations_hidden2)
print(weight_history_dropout_07_std_deviations_hidden2)
# Out:
# [0.04773779958486557, 0.05057547613978386, 0.05197325348854065, 0.05521969869732857, 0.051149509847164154, 0.05640193074941635, 0.049608130007982254, 0.054651711136102676, 0.05194328725337982, 0.05387082323431969]
# [0.05795670300722122, 0.05100170895457268, 0.05977489426732063, 0.05806013569235802, 0.05327661707997322, 0.05867189168930054, 0.05678752809762955, 0.05488220974802971, 0.06047852709889412, 0.056406449526548386]
# [0.06389410048723221, 0.06265634298324585, 0.08157875388860703, 0.08326974511146545, 0.08034878224134445, 0.07432945817708969, 0.08368156850337982, 0.07578703761100769, 0.078833669424057, 0.072905533015728]
# [0.05988101288676262, 0.058579206466674805, 0.06683466583490372, 0.06729347258806229, 0.06622140109539032, 0.06997313350439072, 0.07073371112346649, 0.08402698487043381, 0.07979828119277954, 0.07506071776151657]

# %%
print(weight_history02_std_deviations_output)
print(weight_history_dropout_02_std_deviations_output)
print(weight_history_dropout_05_std_deviations_output)
print(weight_history_dropout_07_std_deviations_output)
# Out:
# [0.10245735198259354, 0.06036067754030228, 0.07394645363092422, 0.06451911479234695, 0.08302658051252365, 0.080492302775383, 0.06062094494700432, 0.11347994208335876, 0.08651265501976013, 0.0895126610994339]
# [0.06338543444871902, 0.08420558273792267, 0.07632696628570557, 0.1009008064866066, 0.08895314484834671, 0.0779384970664978, 0.08040140569210052, 0.10248766094446182, 0.06283456087112427, 0.061671093106269836]
# [0.05674615502357483, 0.11951335519552231, 0.07455570250749588, 0.07951822131872177, 0.06266608089208603, 0.07054608315229416, 0.0685310810804367, 0.04882512614130974, 0.06084243208169937, 0.06687849760055542]
# [0.045995116233825684, 0.057088255882263184, 0.05432021990418434, 0.05362682789564133, 0.03712425380945206, 0.05279833450913429, 0.04429541900753975, 0.052191417664289474, 0.0626201406121254, 0.047553081065416336]
